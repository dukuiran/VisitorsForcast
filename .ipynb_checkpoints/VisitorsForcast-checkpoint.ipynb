# %%
import xgboost as xgb
import pandas as pd
import numpy as np
import scipy as sp
from datetime import datetime,timedelta
from openpyxl import load_workbook,Workbook

hpg_store_info=pd.read_csv('hpg_store_info.csv')
air_store_info=pd.read_csv('air_store_info.csv')
air_reserve=pd.read_csv('air_reserve.csv')
hpg_reserve=pd.read_csv('hpg_reserve.csv')
air_visit_data=pd.read_csv('air_visit_data.csv')
date_info=pd.read_csv('date_info.csv')
store_id_relation=pd.read_csv('store_id_relation.csv')

# %%
hpg_store_loc=[row[3:5] for row in hpg_store_info.itertuples(index=False)]
air_store_loc=[row[3:5] for row in air_store_info.itertuples(index=False)]

# %%
import gmaps
gmaps.configure(api_key="AIzaSyDmJ3Ri0S5gPD_VClxL0882locfzGt8mZQ") # Your Google API key
fig = gmaps.Map()
store_layer = gmaps.symbol_layer(hpg_store_loc,fill_color="green",stroke_color="green",scale=2)   #
fig.add_layer(store_layer)
fig
# Out:
# Map(configuration={'api_key': 'AIzaSyDmJ3Ri0S5gPD_VClxL0882locfzGt8mZQ'}, data_bounds=[(31.533207878866609, 131.28354812722472), (40.087314785862304, 144.07135136104034)], layers=(Markers(data_bounds=[(31.533207878866609, 131.28354812722472), (40.087314785862304, 144.07135136104034)], markers=[Symbol(fill_color='green', location=(35.643674664226502, 139.668220854814), scale=2, stroke_color='green'), Symbol(fill_color='green', location=(35.643674664226502, 139.668220854814), scale=2, stroke_color='green'), Symbol(fill_color='green', location=(35.643674664226502, 139.668220854814), scale=2, stroke_color='green'), Symbol(fill_color='green', location=(35.643674664226502, 139.668220854814), scale=2, stroke_color='green'), Symbol(fill_color='green', location=(35.643674664226502, 139.668220854814), scale=2, stroke_color='green'), Symbol(fill_color='green', location=(35.643674664226502, 139.668220854814), scale=2, stroke_color='green'), Symbol(fill_color='green', location=(35.643674664226502
# ...

# %%
import gmaps
gmaps.configure(api_key="AIzaSyDmJ3Ri0S5gPD_VClxL0882locfzGt8mZQ") # Your Google API key
fig = gmaps.Map()
store_layer = gmaps.symbol_layer(air_store_loc,fill_color="green",stroke_color="green",scale=2)   #
fig.add_layer(store_layer)
fig
# Out:
# Map(configuration={'api_key': 'AIzaSyDmJ3Ri0S5gPD_VClxL0882locfzGt8mZQ'}, data_bounds=[(31.480240209952484, 130.11941047361256), (39.813844096440803, 144.71583355637767)], layers=(Markers(data_bounds=[(31.480240209952484, 130.11941047361256), (39.813844096440803, 144.71583355637767)], markers=[Symbol(fill_color='green', location=(34.695124200000002, 135.19785249999998), scale=2, stroke_color='green'), Symbol(fill_color='green', location=(34.695124200000002, 135.19785249999998), scale=2, stroke_color='green'), Symbol(fill_color='green', location=(34.695124200000002, 135.19785249999998), scale=2, stroke_color='green'), Symbol(fill_color='green', location=(34.695124200000002, 135.19785249999998), scale=2, stroke_color='green'), Symbol(fill_color='green', location=(35.658068100000001, 139.75159919999999), scale=2, stroke_color='green'), Symbol(fill_color='green', location=(35.658068100000001, 139.75159919999999), scale=2, stroke_color='green'), Symbol(fill_color='green', location=(35.658
# ...

# %%
import matplotlib as mplt
import seaborn as sbn
from dateutil.parser import parse

air_reserve_day=air_reserve[:]
# air_reserve_day['visit_datetime']=pd.to_datetime(air_reserve_day['visit_datetime'], format='%Y/%m/%d')
# air_reserve_day['visit_datetime']=pd.to_datetime(air_reserve_day['visit_datetime'], format='%Y/%m/%d')
# air_reserve_day['visit_datetime']=air_reserve_day['visit_datetime'].astype(str).datetime.strftime('%Y-%m-%d')
# air_reserve_day['reserve_datetime']=pd.to_datetime(air_reserve_day['reserve_datetime'], format='%Y/%m/%d')
# air_reserve_day['visit_datetime']=air_reserve_day['visit_datetime'].apply(lambda x: datetime.strptime(x,'%Y-%m-%d'))   # %H:%M:%S
# df['Mycol'] = df['Mycol'].apply(lambda x: dt.datetime.strptime(x,'%d%b%Y:%H:%M:%S.%f'))
# help(gmaps.symbol_layer)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-51-a21914a697bc> in <module>()
#       6 # air_reserve_day['visit_datetime']=pd.to_datetime(air_reserve_day['visit_datetime'], format='%Y/%m/%d')
#       7 # air_reserve_day['visit_datetime']=pd.to_datetime(air_reserve_day['visit_datetime'], format='%Y/%m/%d')
# ----> 8 air_reserve_day['visit_datetime']=air_reserve_day['visit_datetime'].astype(str).datetime.strftime('%Y-%m-%d')
#       9 # air_reserve_day['reserve_datetime']=pd.to_datetime(air_reserve_day['reserve_datetime'], format='%Y/%m/%d')
#      10 # air_reserve_day['visit_datetime']=air_reserve_day['visit_datetime'].apply(lambda x: datetime.strptime(x,'%Y-%m-%d'))   # %H:%M:%S
#
# C:\Users\Administrator\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    2670             if name in self._info_axis:
# ...

# %%
# hpg_store_info.head(5)
# air_store_info.head(5)
# air_reserve.head(5)
# hpg_reserve.head(5)
# air_visit_data.head(5)
# date_info.head(5)
# store_id_relation.head(5)
# hpg_reserve.info()
# print(air_reserve.head(5))
print(air_reserve_day.head())
# air_reserve_day.info()
# Out:
#            air_store_id      visit_datetime     reserve_datetime  \
# 0  air_877f79706adbfb06 2016-01-01 19:00:00  2016-01-01 16:00:00
# 1  air_db4b38ebe7a7ceff 2016-01-01 19:00:00  2016-01-01 19:00:00
# 2  air_db4b38ebe7a7ceff 2016-01-01 19:00:00  2016-01-01 19:00:00
# 3  air_877f79706adbfb06 2016-01-01 20:00:00  2016-01-01 16:00:00
# 4  air_db80363d35f10926 2016-01-01 20:00:00  2016-01-01 01:00:00
#
#    reserve_visitors
# 0                 1
# 1                 3
# 2                 6
# 3                 2
# 4                 5

# %%
# hpg_store_info['hpg_store_id'].drop_duplicates()
parse(air_reserve_day['visit_datetime'].astype(str))  #.datetime.strftime('%Y-%m-%d')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-54-c400b258622f> in <module>()
#       1 # hpg_store_info['hpg_store_id'].drop_duplicates()
# ----> 2 parse(air_reserve_day['visit_datetime'].astype(str))  #.datetime.strftime('%Y-%m-%d')
#
# C:\Users\Administrator\Anaconda3\lib\site-packages\dateutil\parser.py in parse(timestr, parserinfo, **kwargs)
#    1166         return parser(parserinfo).parse(timestr, **kwargs)
#    1167     else:
# -> 1168         return DEFAULTPARSER.parse(timestr, **kwargs)
#    1169
#    1170
#
# C:\Users\Administrator\Anaconda3\lib\site-packages\dateutil\parser.py in parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     554             effective_dt = default
#     555
# --> 556         res, skipped_tokens = self._parse(timestr, **kwargs)
#     557
#     558         if res is None:
#
# ...
